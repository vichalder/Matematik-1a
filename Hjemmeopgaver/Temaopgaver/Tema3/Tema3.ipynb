# %% [markdown]
# # Spørgsmål 1
#
# ![image.png](attachment:image.png)

# %%
import sympy as sp
from sympy import Symbol
from sympy.solvers import solve

x = Symbol('x')

# %% [markdown]
# ## a)
# ![image.png](attachment:image.png)

# %%
U = 12.6
R1 = 3
R2 = 7
Rtotal = R1 + R2
I1 = U/Rtotal
I2 = I1
u = R2*I2

print("u = ", u)
print("I1 = ", I1)
print("I2 = ", I2)
print("Kirchoff: ", I1-I2)
# Out:
# u =  8.82
# I1 =  1.26
# I2 =  1.26
# Kirchoff:  0.0

# %% [markdown]
# ## b)
# ![image.png](attachment:image.png)

# %% [markdown]
# $$u = R2 * U/(R1 + R2)$$

# %% [markdown]
# # Spørgsmål 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ## a)
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{align}
# &R1: u1-U = I1*R1\\
# &R2: u1 = I2*R2\\
# &R3: U - u2 = I3*R3\\
# &R4: u2 = I4*R4\\
# &R5: u1-u2 = I5*R5\\
# \end{align}

# %% [markdown]
# ## b)
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{align}
# &u1: I1+I5-I2 = 0\\
# &u2: I3-I5-I4 = 0\\
# &I2 = I1+I5\\
# &I4 = I3-I5
# \end{align}

# %% [markdown]
# ## c)
# ![image.png](attachment:image.png)

# %%
U = 12.6
R1 = 6
R3 = 7
R2 = 3
R4 = R2
R5 = 4

# %% [markdown]
# ## d)

# %% [markdown]
# ## e)

# %% [markdown]
# ## f)

# %% [markdown]
# # Spørgsmål 3

# %% [markdown]
# ## a)

# %% [markdown]
# ## b)

# %% [markdown]
# ## c)

# %% [markdown]
# ## d)

# %% [markdown]
# ## e)
