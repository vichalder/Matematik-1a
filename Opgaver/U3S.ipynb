# %% [markdown]
# # Uge 3 store dag

# %%
from sympy import *

# %% [markdown]
# ## Opgave 1

# %% [markdown]
# ### a
# ![image.png](attachment:image.png)
# <br>
# i^2 = -1 <br>
# i^3 = -i <br>
# i^4 = 1 <br>
# i^5 = i <br>
# (-i)^2 = -1 <br>
# (-i)^3 = i <br>
# (-i)^4 = 1 <br>
# (-i)^(-5) = i <br>

# %% [markdown]
# ### b
# ![image.png](attachment:image.png)
# <br>
# $Re(10+i)=10$ <br>
# $Im(10+i)=1$ <br>
# $Re(i)=0$ <br>
# $Im(i)=1$ <br>
# $Re(-5-i7)=-5$ <br>
# $Im(-5-i7)=-7$

# %% [markdown]
# ### c
# ![image.png](attachment:image.png)
# <br>
# $Re(-5-i7)=-5$ <br>
# $Im(-5-i7)=-7$

# %% [markdown]
# ### d
# ![image.png](attachment:image.png)
# <br>
# $-5+7i$ <br>
# $-7-5i$ <br>
# $5-7i$

# %% [markdown]
# # Opgave 2

# %% [markdown]
# ### a
# ![image.png](attachment:image.png)
# <br>
# ![image-2.png](attachment:image-2.png)
# <br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### b
# ![image.png](attachment:image.png)
# <br>
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Opgave 3

# %% [markdown]
# ### a
# ![image.png](attachment:image.png)
# <br>
# 1. $(5+i)(1+9i)=5*1+5*9i+1*i+i*9i=5+45i+i-9=-4+46i$ <br>
# 2. $i+i^2+i^3+i^4=i-1-i+1=0$ <br>
# 3. $1/1+3i+1/(1+3i)^2=1/50-9/50i$ <br>
# 4. $-1/4$ <br>
# 5. $1+3/2i$ <br>
# 6. $3/4i$ <br>
# 7. $1/2i$

# %%
sympify((1/1+3j)+(1/(1+3j)**2))
# Out:
# 0.92 + 2.94*I

# %% [markdown]
# ### b
# ![image.png](attachment:image.png)
# <br>
# 1. Tallet er ikke på rektangulær form, da man ikke kan splitte tælleren op og få en Im del og en Re del.
# 2. $Re(1/a+ib)=a/(a^2+b^2)$ og $Im(1/a+ib)=-b/(a^2+b^2)$

# %% [markdown]
# ## Opgave 4
# ![image.png](attachment:image.png)

# %% [markdown]
# ## a
# ![image.png](attachment:image.png)
# <br>
