# %% [markdown]
# # Uge 3 store dag

# %% [markdown]
# # Opgave 1

# %% [markdown]
# # a
# ![image.png](attachment:image.png)
# <br>
# i^2 = -1 <br>
# i^3 = -i <br>
# i^4 = 1 <br>
# i^5 = i <br>
# (-i)^2 = -1 <br>
# (-i)^3 = i <br>
# (-i)^4 = 1 <br>
# (-i)^(-5) = i <br>

# %% [markdown]
# # b
# ![image.png](attachment:image.png)
# <br>
# Re(10+i)=10 <br>
# Im(10+i)=1 <br>
# Re(i)=0 <br>
# Im(i)=1 <br>
# Re(-5-i7)=-5 <br>
# Im(-5-i7)=-7

# %% [markdown]
# # c
# ![image.png](attachment:image.png)
# <br>
# Re(-5-i7)=-5 <br>
# Im(-5-i7)=-7

# %% [markdown]
# # d
# ![image.png](attachment:image.png)
# <br>
# -5+7i <br>
# -7-5i <br>
# 5-7i
